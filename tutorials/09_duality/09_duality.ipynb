# %% [markdown]
# # 9. Duality and Complements
#
# Cover the three dual/conjugate operations in pytanga: the unsigned bitwise complement (~MV), the signed Clifford dual (MV.dual()), and the left dual (MV.ldual()). Explain the mathematical meaning of each, when to use each one, and how they interact across the four basis algebras. Include practical use cases: mapping between IPNS and OPNS, computing the regressive product via duality, and extracting normals/orthogonal complements.

# %% [markdown]
# **TBD — content not yet implemented.**
