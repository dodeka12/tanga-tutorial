# %% [markdown]
# # 2. Installation and First Steps
#
# Walk through installing pytanga with uv/pip, verifying the installation, calling pytanga.install_docs() for AI-tool documentation access, and running a minimal "hello world" multivector operation to confirm everything works. Covers the on-demand C++ compilation model, pre-compiled wheels, and the environment setup.

# %% [markdown]
# **TBD — content not yet implemented.**
