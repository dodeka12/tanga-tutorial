# %% [markdown]
# # 7. Conformal / Null 3D (G(5,0)⊕[B₁,0,0,0]) — Spheres, Circles, Point Pairs
#
# Deep dive into BasisN3. Explain the null-vector embedding (e0, e∞), IPNS vs OPNS representations, and how spheres, circles, point pairs, lines, and planes emerge as blades. Build a sphere from a center and radius, extract center and radius from a sphere. Construct circles as intersections of spheres. Show the distinction between IPNS entities (as analyze output) and OPNS constructions. Introduce N3 operators: rotors, translators, dilators, and the inversion operator.

# %% [markdown]
# **TBD — content not yet implemented.**
