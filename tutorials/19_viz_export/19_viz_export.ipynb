# %% [markdown]
# # 19. Visualization — Export and Publishing
#
# Export visualizations for sharing and publication. Generate self-contained HTML files (with embedded JS animation engine), embeddable HTML for iframes (Reveal.js slides), glTF/GLB for use in other 3D tools, PNG screenshots (programmatic), MP4 video capture, and presentation figures with FigureStyle and SceneExporter. Cover animated HTML export that preserves keyframe timelines.

# %% [markdown]
# **TBD — content not yet implemented.**
