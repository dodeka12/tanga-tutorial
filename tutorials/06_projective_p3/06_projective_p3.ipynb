# %% [markdown]
# # 6. Projective 3D (G(4,0)) — Homogeneous Coordinates
#
# Deep dive into BasisP3. Introduce the homogeneous (projective) embedding where a fourth basis vector e0 carries the origin. Show how points, directions, lines, and planes are represented as blades. Demonstrate perspective projection, translation via projective rotors, and the relationship between projective and Euclidean entities. Highlight the geometry submodule's analyze() and create() as shortcuts for working with P3 entities.

# %% [markdown]
# **TBD — content not yet implemented.**
